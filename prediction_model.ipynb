# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result  gf  ga  \
# 0  2023-08-12  21:30  La Liga  Matchweek 1  Sat  Away      W   2   0
# 1  2023-08-19  19:30  La Liga  Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga  Matchweek 3  Fri  Away      W   1   0
# 3  2023-09-02  16:15  La Liga  Matchweek 4  Sat  Home      W   2   1
# 4  2023-09-17  21:00  La Liga  Matchweek 5  Sun  Home      W   2   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0  Athletic Club  ...  Match Report    NaN  14.0   8.0  16.0  2.0  0     0
# 1        Almería  ...  Match Report    NaN  25.0   9.0  17.0  1.0  0     0
# 2     Celta Vigo  ...  Match Report    NaN   9.0   2.0  19.4  0.0  0     1
# 3         Getafe  ...  Match Report    NaN  26.0  12.0  17.7  0.0  0     0
# 4  Real Sociedad  ...  Match Report    NaN  17.0   8.0  15.9  1.0  0     0
#
#    season         team
# 0    2024  Real Madrid
# 1    2024  Real Madrid
# 2    2024  Real Madrid
# 3    2024  Real Madrid
# 4    2024  Real Madrid
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1520, 27)

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W   2   0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W   1   0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W   2   1
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W   2   1
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 36 2023-05-14  16:15  La Liga  Matchweek 34  Sun  Home      W   1   0
# 37 2023-05-20  18:30  La Liga  Matchweek 35  Sat  Away      D   1   1
# 38 2023-05-24  19:30  La Liga  Matchweek 36  Wed  Home      D   1   1
# 39 2023-05-28  19:00  La Liga  Matchweek 37  Sun  Away      W   1   0
# 40 2023-06-04  21:00  La Liga  Matchweek 38  Sun  Home      D   1   1
#
#            opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0     Athletic Club  ...  Match Report    NaN  14.0   8.0  16.0  2.0  0     0
# 1           Almería  ...  Match Report    NaN  25.0   9.0  17.0  1.0  0     0
# 2        Celta Vigo  ...  Match Report    NaN   9.0   2.0  19.4  0.0  0     1
# 3            Getafe  ...  Match Report    NaN  26.0  12.0  17.7  0.0  0     0
# 4     Real Sociedad  ...  Match Report    NaN  17.0   8.0  15.9  1.0  0     0
# ..              ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 36  Atlético Madrid  ...  Match Report    NaN  15.0   4.0  13.4  0.0  0     0
# 37           Getafe  ...  Match Report    NaN  13.0   4.0  12.8  0.0  0     0
# 38          Sevilla  ...  Match Report    NaN  20.0   7.0  17.5  0.0  0     0
# 39    Athletic Club  ...  Match Report    NaN   6.0   2.0  14.2  0.0  0     0
# 40            Cádiz  ...  Match Report    NaN  12.0   5.0  15.8  0.0  0     0
#
#     season         team
# 0     2024  Real Madrid
# 1     2024  Real Madrid
# 2     2024  Real Madrid
# 3     2024  Real Madrid
# 4     2024  Real Madrid
# ..     ...          ...
# 36    2023        Elche
# 37    2023        Elche
# 38    2023        Elche
# 39    2023        Elche
# 40    2023        Elche
#
# [1520 rows x 27 columns]

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W   2   0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W   1   0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W   2   1
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W   2   1
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 36 2023-05-14  16:15  La Liga  Matchweek 34  Sun  Home      W   1   0
# 37 2023-05-20  18:30  La Liga  Matchweek 35  Sat  Away      D   1   1
# 38 2023-05-24  19:30  La Liga  Matchweek 36  Wed  Home      D   1   1
# 39 2023-05-28  19:00  La Liga  Matchweek 37  Sun  Away      W   1   0
# 40 2023-06-04  21:00  La Liga  Matchweek 38  Sun  Home      D   1   1
#
#            opponent  ...  notes    sh   sot  dist   fk pk pkatt season  \
# 0     Athletic Club  ...    NaN  14.0   8.0  16.0  2.0  0     0   2024
# 1           Almería  ...    NaN  25.0   9.0  17.0  1.0  0     0   2024
# 2        Celta Vigo  ...    NaN   9.0   2.0  19.4  0.0  0     1   2024
# 3            Getafe  ...    NaN  26.0  12.0  17.7  0.0  0     0   2024
# 4     Real Sociedad  ...    NaN  17.0   8.0  15.9  1.0  0     0   2024
# ..              ...  ...    ...   ...   ...   ...  ... ..   ...    ...
# 36  Atlético Madrid  ...    NaN  15.0   4.0  13.4  0.0  0     0   2023
# 37           Getafe  ...    NaN  13.0   4.0  12.8  0.0  0     0   2023
# 38          Sevilla  ...    NaN  20.0   7.0  17.5  0.0  0     0   2023
# 39    Athletic Club  ...    NaN   6.0   2.0  14.2  0.0  0     0   2023
# 40            Cádiz  ...    NaN  12.0   5.0  15.8  0.0  0     0   2023
#
#            team  venue_code
# 0   Real Madrid           0
# 1   Real Madrid           0
# 2   Real Madrid           0
# 3   Real Madrid           1
# 4   Real Madrid           1
# ..          ...         ...
# 36        Elche           1
# 37        Elche           0
# 38        Elche           1
# 39        Elche           0
# 40        Elche           1
#
# [1520 rows x 28 columns]

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W   2   0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W   1   0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W   2   1
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W   2   1
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 36 2023-05-14  16:15  La Liga  Matchweek 34  Sun  Home      W   1   0
# 37 2023-05-20  18:30  La Liga  Matchweek 35  Sat  Away      D   1   1
# 38 2023-05-24  19:30  La Liga  Matchweek 36  Wed  Home      D   1   1
# 39 2023-05-28  19:00  La Liga  Matchweek 37  Sun  Away      W   1   0
# 40 2023-06-04  21:00  La Liga  Matchweek 38  Sun  Home      D   1   1
#
#            opponent  ...    sh   sot  dist   fk pk pkatt season         team  \
# 0     Athletic Club  ...  14.0   8.0  16.0  2.0  0     0   2024  Real Madrid
# 1           Almería  ...  25.0   9.0  17.0  1.0  0     0   2024  Real Madrid
# 2        Celta Vigo  ...   9.0   2.0  19.4  0.0  0     1   2024  Real Madrid
# 3            Getafe  ...  26.0  12.0  17.7  0.0  0     0   2024  Real Madrid
# 4     Real Sociedad  ...  17.0   8.0  15.9  1.0  0     0   2024  Real Madrid
# ..              ...  ...   ...   ...   ...  ... ..   ...    ...          ...
# 36  Atlético Madrid  ...  15.0   4.0  13.4  0.0  0     0   2023        Elche
# 37           Getafe  ...  13.0   4.0  12.8  0.0  0     0   2023        Elche
# 38          Sevilla  ...  20.0   7.0  17.5  0.0  0     0   2023        Elche
# 39    Athletic Club  ...   6.0   2.0  14.2  0.0  0     0   2023        Elche
# 40            Cádiz  ...  12.0   5.0  15.8  0.0  0     0   2023        Elche
#
#     venue_code  opp_code
# 0            0         2
# 1            0         1
# 2            0         6
# 3            1        10
# 4            1        18
# ..         ...       ...
# 36           1         3
# 37           0        10
# 38           1        19
# 39           0         2
# 40           1         7
#
# [1520 rows x 29 columns]

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W   2   0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W   1   0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W   2   1
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W   2   1
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 36 2023-05-14  16:15  La Liga  Matchweek 34  Sun  Home      W   1   0
# 37 2023-05-20  18:30  La Liga  Matchweek 35  Sat  Away      D   1   1
# 38 2023-05-24  19:30  La Liga  Matchweek 36  Wed  Home      D   1   1
# 39 2023-05-28  19:00  La Liga  Matchweek 37  Sun  Away      W   1   0
# 40 2023-06-04  21:00  La Liga  Matchweek 38  Sun  Home      D   1   1
#
#            opponent  ...   sot  dist   fk  pk pkatt season         team  \
# 0     Athletic Club  ...   8.0  16.0  2.0   0     0   2024  Real Madrid
# 1           Almería  ...   9.0  17.0  1.0   0     0   2024  Real Madrid
# 2        Celta Vigo  ...   2.0  19.4  0.0   0     1   2024  Real Madrid
# 3            Getafe  ...  12.0  17.7  0.0   0     0   2024  Real Madrid
# 4     Real Sociedad  ...   8.0  15.9  1.0   0     0   2024  Real Madrid
# ..              ...  ...   ...   ...  ...  ..   ...    ...          ...
# 36  Atlético Madrid  ...   4.0  13.4  0.0   0     0   2023        Elche
# 37           Getafe  ...   4.0  12.8  0.0   0     0   2023        Elche
# 38          Sevilla  ...   7.0  17.5  0.0   0     0   2023        Elche
# 39    Athletic Club  ...   2.0  14.2  0.0   0     0   2023        Elche
# 40            Cádiz  ...   5.0  15.8  0.0   0     0   2023        Elche
#
#    venue_code  opp_code  hour
# 0           0         2    21
# 1           0         1    19
# 2           0         6    21
# 3           1        10    16
# 4           1        18    21
# ..        ...       ...   ...
# 36          1         3    16
# 37          0        10    18
# 38          1        19    19
# 39          0         2    19
# 40          1         7    21
#
# [1520 rows x 30 columns]

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W   2   0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W   1   0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W   2   1
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W   2   1
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 36 2023-05-14  16:15  La Liga  Matchweek 34  Sun  Home      W   1   0
# 37 2023-05-20  18:30  La Liga  Matchweek 35  Sat  Away      D   1   1
# 38 2023-05-24  19:30  La Liga  Matchweek 36  Wed  Home      D   1   1
# 39 2023-05-28  19:00  La Liga  Matchweek 37  Sun  Away      W   1   0
# 40 2023-06-04  21:00  La Liga  Matchweek 38  Sun  Home      D   1   1
#
#            opponent  ...  dist   fk  pk  pkatt season         team venue_code  \
# 0     Athletic Club  ...  16.0  2.0   0      0   2024  Real Madrid          0
# 1           Almería  ...  17.0  1.0   0      0   2024  Real Madrid          0
# 2        Celta Vigo  ...  19.4  0.0   0      1   2024  Real Madrid          0
# 3            Getafe  ...  17.7  0.0   0      0   2024  Real Madrid          1
# 4     Real Sociedad  ...  15.9  1.0   0      0   2024  Real Madrid          1
# ..              ...  ...   ...  ...  ..    ...    ...          ...        ...
# 36  Atlético Madrid  ...  13.4  0.0   0      0   2023        Elche          1
# 37           Getafe  ...  12.8  0.0   0      0   2023        Elche          0
# 38          Sevilla  ...  17.5  0.0   0      0   2023        Elche          1
# 39    Athletic Club  ...  14.2  0.0   0      0   2023        Elche          0
# 40            Cádiz  ...  15.8  0.0   0      0   2023        Elche          1
#
#    opp_code  hour  day_code
# 0         2    21         5
# 1         1    19         5
# 2         6    21         4
# 3        10    16         5
# 4        18    21         6
# ..      ...   ...       ...
# 36        3    16         6
# 37       10    18         5
# 38       19    19         2
# 39        2    19         6
# 40        7    21         6
#
# [1520 rows x 31 columns]

# %%
matches["target"] = (matches["result"] =="W").astype("int")

# %%
matches
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W   2   0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W   3   1
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W   1   0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W   2   1
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W   2   1
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 36 2023-05-14  16:15  La Liga  Matchweek 34  Sun  Home      W   1   0
# 37 2023-05-20  18:30  La Liga  Matchweek 35  Sat  Away      D   1   1
# 38 2023-05-24  19:30  La Liga  Matchweek 36  Wed  Home      D   1   1
# 39 2023-05-28  19:00  La Liga  Matchweek 37  Sun  Away      W   1   0
# 40 2023-06-04  21:00  La Liga  Matchweek 38  Sun  Home      D   1   1
#
#            opponent  ...   fk  pk  pkatt  season         team venue_code  \
# 0     Athletic Club  ...  2.0   0      0    2024  Real Madrid          0
# 1           Almería  ...  1.0   0      0    2024  Real Madrid          0
# 2        Celta Vigo  ...  0.0   0      1    2024  Real Madrid          0
# 3            Getafe  ...  0.0   0      0    2024  Real Madrid          1
# 4     Real Sociedad  ...  1.0   0      0    2024  Real Madrid          1
# ..              ...  ...  ...  ..    ...     ...          ...        ...
# 36  Atlético Madrid  ...  0.0   0      0    2023        Elche          1
# 37           Getafe  ...  0.0   0      0    2023        Elche          0
# 38          Sevilla  ...  0.0   0      0    2023        Elche          1
# 39    Athletic Club  ...  0.0   0      0    2023        Elche          0
# 40            Cádiz  ...  0.0   0      0    2023        Elche          1
#
#    opp_code hour  day_code  target
# 0         2   21         5       1
# 1         1   19         5       1
# 2         6   21         4       1
# 3        10   16         5       1
# 4        18   21         6       1
# ..      ...  ...       ...     ...
# 36        3   16         6       1
# 37       10   18         5       0
# 38       19   19         2       0
# 39        2   19         6       1
# 40        7   21         6       0
#
# [1520 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split =10, random_state = 1)

# %%
train = matches[matches["date"] < '2024-01-01']

# %%
test = matches[matches["date"] > '2024-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.62

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           193  57
# 1            95  55

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.49107142857142855

# %%
grouped_matches = matches.groupby("team")

# %%
group =grouped_matches.get_group("Barcelona")

# %% [raw]
# group

# %%
print(group)
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-08-13  21:30  La Liga   Matchweek 1  Sun  Away      D   0   0
# 1  2023-08-20  19:30  La Liga   Matchweek 2  Sun  Home      W   2   0
# 2  2023-08-27  17:30  La Liga   Matchweek 3  Sun  Away      W   4   3
# 3  2023-09-03  21:00  La Liga   Matchweek 4  Sun  Away      W   2   1
# 4  2023-09-16  21:00  La Liga   Matchweek 5  Sat  Home      W   5   0
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 48 2023-05-14  21:00  La Liga  Matchweek 34  Sun  Away      W   4   2
# 49 2023-05-20  21:00  La Liga  Matchweek 35  Sat  Home      L   1   2
# 50 2023-05-23  22:00  La Liga  Matchweek 36  Tue  Away      L   1   3
# 51 2023-05-28  19:00  La Liga  Matchweek 37  Sun  Home      W   3   0
# 52 2023-06-04  21:00  La Liga  Matchweek 38  Sun  Away      L   1   2
#
#          opponent  ...   fk  pk  pkatt  season       team venue_code opp_code  \
# 0          Getafe  ...  1.0   0      0    2024  Barcelona          0       10
# 1           Cádiz  ...  2.0   0      0    2024  Barcelona          1        7
# 2      Villarreal  ...  0.0   0      0    2024  Barcelona          0       22
# 3         Osasuna  ...  0.0   1      1    2024  Barcelona          0       15
# 4           Betis  ...  2.0   0      0    2024  Barcelona          1        5
# ..            ...  ...  ...  ..    ...     ...        ...        ...      ...
# 48       Espanyol  ...  0.0   0      0    2023  Barcelona          0        9
# 49  Real Sociedad  ...  1.0   0      0    2023  Barcelona          1       18
# 50     Valladolid  ...  1.0   0      0    2023  Barcelona          0       21
# 51       Mallorca  ...  3.0   0      0    2023  Barcelona          1       14
# 52     Celta Vigo  ...  0.0   0      0    2023  Barcelona          0        6
#
#    hour  day_code  target
# 0    21         6       0
# 1    19         6       1
# 2    17         6       1
# 3    21         6       1
# 4    21         5       1
# ..  ...       ...     ...
# 48   21         6       1
# 49   21         5       0
# 50   22         1       0
# 51   19         6       1
# 52   21         6       0
#
# [76 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(5, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 7  2022-09-17  16:15  La Liga   Matchweek 6  Sat  Home      W   3   0
# 8  2022-10-01  21:00  La Liga   Matchweek 7  Sat  Away      W   1   0
# 10 2022-10-09  21:00  La Liga   Matchweek 8  Sun  Home      W   1   0
# 12 2022-10-16  16:15  La Liga   Matchweek 9  Sun  Away      L   1   3
# 13 2022-10-20  21:00  La Liga  Matchweek 10  Thu  Home      W   3   0
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 48 2024-05-04  18:30  La Liga  Matchweek 34  Sat  Away      L   2   4
# 49 2024-05-13  21:00  La Liga  Matchweek 35  Mon  Home      W   2   0
# 50 2024-05-16  21:30  La Liga  Matchweek 36  Thu  Away      W   2   0
# 51 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Home      W   3   0
# 52 2024-05-26  21:00  La Liga  Matchweek 38  Sun  Away      W   2   1
#
#           opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 7            Elche  ...         5       1         3.0         0.2       18.8
# 8         Mallorca  ...         5       1         3.6         0.2       19.6
# 10      Celta Vigo  ...         6       1         3.0         0.0       18.8
# 12     Real Madrid  ...         6       0         2.4         0.0       16.6
# 13      Villarreal  ...         3       1         2.0         0.6       16.6
# ..             ...  ...       ...     ...         ...         ...        ...
# 48          Girona  ...         5       0         2.2         1.0       15.4
# 49   Real Sociedad  ...         0       1         2.0         1.8       16.6
# 50         Almería  ...         3       1         2.2         1.8       16.4
# 51  Rayo Vallecano  ...         6       1         2.4         1.8       17.2
# 52         Sevilla  ...         6       1         2.6         1.2       17.0
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 7          6.8        15.38        0.8         0.0            0.0
# 8          7.6        14.98        0.6         0.0            0.0
# 10         6.8        15.80        0.6         0.0            0.0
# 12         6.0        15.74        0.4         0.0            0.0
# 13         6.0        15.66        0.2         0.0            0.0
# ..         ...          ...        ...         ...            ...
# 48         5.4        16.88        1.2         0.0            0.0
# 49         5.6        17.26        1.0         0.2            0.2
# 50         6.0        18.04        1.0         0.4            0.4
# 51         7.2        17.38        1.0         0.4            0.4
# 52         7.2        17.42        0.8         0.4            0.4
#
# [71 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/lw/gv43dfbx1_ldfr7qwh5skqvr0000gn/T/ipykernel_9759/4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                     date   time     comp         round  day venue result  gf  \
# team
# Alaves     5  2023-09-22  21:00  La Liga   Matchweek 6  Fri  Home      L   0
#            6  2023-09-28  19:00  La Liga   Matchweek 7  Thu  Away      D   1
#            7  2023-10-01  16:15  La Liga   Matchweek 8  Sun  Home      L   0
#            8  2023-10-08  18:30  La Liga   Matchweek 9  Sun  Home      D   1
#            9  2023-10-22  18:30  La Liga  Matchweek 10  Sun  Away      D   1
# ...                  ...    ...      ...           ...  ...   ...    ...  ..
# Villarreal 44 2024-05-05  16:15  La Liga  Matchweek 34  Sun  Away      L   2
#            45 2024-05-11  16:15  La Liga  Matchweek 35  Sat  Home      W   3
#            46 2024-05-14  22:00  La Liga  Matchweek 36  Tue  Away      W   1
#            47 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Home      D   4
#            48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1
#
#                ga       opponent  ...  day_code  target  gf_rolling  \
# team                              ...
# Alaves     5    2  Athletic Club  ...         4       0         1.0
#            6    1     Celta Vigo  ...         3       0         1.0
#            7    2        Osasuna  ...         6       0         0.4
#            8    1          Betis  ...         6       0         0.4
#            9    1     Villarreal  ...         6       0         0.4
# ...            ..            ...  ...       ...     ...         ...
# Villarreal 44   3     Celta Vigo  ...         6       0         1.6
#            45   2        Sevilla  ...         5       1         1.8
#            46   0         Girona  ...         1       1         2.2
#            47   4    Real Madrid  ...         6       0         2.2
#            48   1        Osasuna  ...         5       0         2.6
#
#                ga_rolling sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Alaves     5          1.4       11.0         2.2        17.82        0.4
#            6          1.6       12.0         2.8        16.48        0.4
#            7          1.2       13.4         3.2        16.24        0.4
#            8          1.4       13.6         3.6        16.20        0.6
#            9          1.6       15.4         4.6        16.36        1.0
# ...                   ...        ...         ...          ...        ...
# Villarreal 44         0.8       11.4         3.8        16.50        0.0
#            45         1.4       11.2         3.2        17.96        0.0
#            46         1.4       14.0         4.2        17.78        0.0
#            47         1.2       14.6         4.6        17.76        0.0
#            48         1.8       16.6         5.4        17.40        0.0
#
#                pk_rolling  pkatt_rolling
# team
# Alaves     5          0.0            0.2
#            6          0.0            0.2
#            7          0.0            0.2
#            8          0.0            0.2
#            9          0.0            0.0
# ...                   ...            ...
# Villarreal 44         0.2            0.6
#            45         0.2            0.4
#            46         0.2            0.4
#            47         0.0            0.0
#            48         0.0            0.0
#
# [1405 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 5  2023-09-22  21:00  La Liga   Matchweek 6  Fri  Home      L   0   2
# 6  2023-09-28  19:00  La Liga   Matchweek 7  Thu  Away      D   1   1
# 7  2023-10-01  16:15  La Liga   Matchweek 8  Sun  Home      L   0   2
# 8  2023-10-08  18:30  La Liga   Matchweek 9  Sun  Home      D   1   1
# 9  2023-10-22  18:30  La Liga  Matchweek 10  Sun  Away      D   1   1
# ..        ...    ...      ...           ...  ...   ...    ...  ..  ..
# 44 2024-05-05  16:15  La Liga  Matchweek 34  Sun  Away      L   2   3
# 45 2024-05-11  16:15  La Liga  Matchweek 35  Sat  Home      W   3   2
# 46 2024-05-14  22:00  La Liga  Matchweek 36  Tue  Away      W   1   0
# 47 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Home      D   4   4
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1   1
#
#          opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 5   Athletic Club  ...         4       0         1.0         1.4       11.0
# 6      Celta Vigo  ...         3       0         1.0         1.6       12.0
# 7         Osasuna  ...         6       0         0.4         1.2       13.4
# 8           Betis  ...         6       0         0.4         1.4       13.6
# 9      Villarreal  ...         6       0         0.4         1.6       15.4
# ..            ...  ...       ...     ...         ...         ...        ...
# 44     Celta Vigo  ...         6       0         1.6         0.8       11.4
# 45        Sevilla  ...         5       1         1.8         1.4       11.2
# 46         Girona  ...         1       1         2.2         1.4       14.0
# 47    Real Madrid  ...         6       0         2.2         1.2       14.6
# 48        Osasuna  ...         5       0         2.6         1.8       16.6
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 5          2.2        17.82        0.4         0.0            0.2
# 6          2.8        16.48        0.4         0.0            0.2
# 7          3.2        16.24        0.4         0.0            0.2
# 8          3.6        16.20        0.6         0.0            0.2
# 9          4.6        16.36        1.0         0.0            0.0
# ..         ...          ...        ...         ...            ...
# 44         3.8        16.50        0.0         0.2            0.6
# 45         3.2        17.96        0.0         0.2            0.4
# 46         4.2        17.78        0.0         0.2            0.4
# 47         4.6        17.76        0.0         0.0            0.0
# 48         5.4        17.40        0.0         0.0            0.0
#
# [1405 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time     comp         round  day venue result  gf  ga  \
# 0    2023-09-22  21:00  La Liga   Matchweek 6  Fri  Home      L   0   2
# 1    2023-09-28  19:00  La Liga   Matchweek 7  Thu  Away      D   1   1
# 2    2023-10-01  16:15  La Liga   Matchweek 8  Sun  Home      L   0   2
# 3    2023-10-08  18:30  La Liga   Matchweek 9  Sun  Home      D   1   1
# 4    2023-10-22  18:30  La Liga  Matchweek 10  Sun  Away      D   1   1
# ...         ...    ...      ...           ...  ...   ...    ...  ..  ..
# 1400 2024-05-05  16:15  La Liga  Matchweek 34  Sun  Away      L   2   3
# 1401 2024-05-11  16:15  La Liga  Matchweek 35  Sat  Home      W   3   2
# 1402 2024-05-14  22:00  La Liga  Matchweek 36  Tue  Away      W   1   0
# 1403 2024-05-19  19:00  La Liga  Matchweek 37  Sun  Home      D   4   4
# 1404 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D   1   1
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 0     Athletic Club  ...         4       0         1.0         1.4       11.0
# 1        Celta Vigo  ...         3       0         1.0         1.6       12.0
# 2           Osasuna  ...         6       0         0.4         1.2       13.4
# 3             Betis  ...         6       0         0.4         1.4       13.6
# 4        Villarreal  ...         6       0         0.4         1.6       15.4
# ...             ...  ...       ...     ...         ...         ...        ...
# 1400     Celta Vigo  ...         6       0         1.6         0.8       11.4
# 1401        Sevilla  ...         5       1         1.8         1.4       11.2
# 1402         Girona  ...         1       1         2.2         1.4       14.0
# 1403    Real Madrid  ...         6       0         2.2         1.2       14.6
# 1404        Osasuna  ...         5       0         2.6         1.8       16.6
#
#      sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0            2.2        17.82        0.4         0.0            0.2
# 1            2.8        16.48        0.4         0.0            0.2
# 2            3.2        16.24        0.4         0.0            0.2
# 3            3.6        16.20        0.6         0.0            0.2
# 4            4.6        16.36        1.0         0.0            0.0
# ...          ...          ...        ...         ...            ...
# 1400         3.8        16.50        0.0         0.2            0.6
# 1401         3.2        17.96        0.0         0.2            0.4
# 1402         4.2        17.78        0.0         0.2            0.4
# 1403         4.6        17.76        0.0         0.0            0.0
# 1404         5.4        17.40        0.0         0.0            0.0
#
# [1405 rows x 40 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-01-01']
    test = data[data["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted = preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.4819277108433735

# %%
combined
# Out:
#       actual  predicted
# 13         0          0
# 14         1          1
# 15         1          1
# 16         1          0
# 17         0          0
# ...      ...        ...
# 1400       0          0
# 1401       1          1
# 1402       1          0
# 1403       0          1
# 1404       0          1
#
# [400 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  predicted       date        team       opponent result
# 13         0          0 2024-01-02      Alaves  Real Sociedad      D
# 14         1          1 2024-01-12      Alaves        Sevilla      W
# 15         1          1 2024-01-19      Alaves          Cádiz      W
# 16         1          0 2024-01-26      Alaves        Almería      W
# 17         0          0 2024-02-03      Alaves      Barcelona      L
# ...      ...        ...        ...         ...            ...    ...
# 1400       0          0 2024-05-05  Villarreal     Celta Vigo      L
# 1401       1          1 2024-05-11  Villarreal        Sevilla      W
# 1402       1          0 2024-05-14  Villarreal         Girona      W
# 1403       0          1 2024-05-19  Villarreal    Real Madrid      D
# 1404       0          1 2024-05-25  Villarreal        Osasuna      D
#
# [400 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key:key

map_values = {
    "Atlético Madrid": "Atletico Madrid",
    "Cádiz" : "Cadiz",
    "Alavés": "Alaves",
    "Almería": "Almeria"
}
mapping = MissingDict(**map_values)

# %%
mapping["Real Madrid"]
# Out:
# 'Real Madrid'

# %%
mapping["Atlético Madrid"]
# Out:
# 'Atletico Madrid'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date        team       opponent result  \
# 13         0          0 2024-01-02      Alaves  Real Sociedad      D
# 14         1          1 2024-01-12      Alaves        Sevilla      W
# 15         1          1 2024-01-19      Alaves          Cádiz      W
# 16         1          0 2024-01-26      Alaves        Almería      W
# 17         0          0 2024-02-03      Alaves      Barcelona      L
# ...      ...        ...        ...         ...            ...    ...
# 1400       0          0 2024-05-05  Villarreal     Celta Vigo      L
# 1401       1          1 2024-05-11  Villarreal        Sevilla      W
# 1402       1          0 2024-05-14  Villarreal         Girona      W
# 1403       0          1 2024-05-19  Villarreal    Real Madrid      D
# 1404       0          1 2024-05-25  Villarreal        Osasuna      D
#
#         new_team
# 13        Alaves
# 14        Alaves
# 15        Alaves
# 16        Alaves
# 17        Alaves
# ...          ...
# 1400  Villarreal
# 1401  Villarreal
# 1402  Villarreal
# 1403  Villarreal
# 1404  Villarreal
#
# [400 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on = ["date", "new_team"], right_on= ["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date         team_x     opponent_x result_x  \
# 0           1            0 2024-01-04  Athletic Club        Sevilla        W
# 1           1            1 2024-01-13  Athletic Club  Real Sociedad        W
# 2           0            1 2024-01-20  Athletic Club       Valencia        L
# 3           0            0 2024-01-28  Athletic Club          Cádiz        D
# 4           1            1 2024-02-02  Athletic Club       Mallorca        W
# ..        ...          ...        ...            ...            ...      ...
# 295         0            0 2024-05-05     Villarreal     Celta Vigo        L
# 296         1            1 2024-05-11     Villarreal        Sevilla        W
# 297         1            0 2024-05-14     Villarreal         Girona        W
# 298         0            1 2024-05-19     Villarreal    Real Madrid        D
# 299         0            1 2024-05-25     Villarreal        Osasuna        D
#
#         new_team_x  actual_y  predicted_y         team_y     opponent_y  \
# 0    Athletic Club         0            0        Sevilla  Athletic Club
# 1    Athletic Club         0            0  Real Sociedad  Athletic Club
# 2    Athletic Club         1            0       Valencia  Athletic Club
# 3    Athletic Club         0            0          Cadiz  Athletic Club
# 4    Athletic Club         0            0       Mallorca  Athletic Club
# ..             ...       ...          ...            ...            ...
# 295     Villarreal         1            0     Celta Vigo     Villarreal
# 296     Villarreal         0            0        Sevilla     Villarreal
# 297     Villarreal         0            0         Girona     Villarreal
# 298     Villarreal         0            0    Real Madrid     Villarreal
# 299     Villarreal         0            0        Osasuna     Villarreal
#
#     result_y     new_team_y
# 0          L        Sevilla
# 1          L  Real Sociedad
# 2          W       Valencia
# 3          D          Cadiz
# 4          L       Mallorca
# ..       ...            ...
# 295        W     Celta Vigo
# 296        L        Sevilla
# 297        L         Girona
# 298        D    Real Madrid
# 299        D        Osasuna
#
# [300 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    34
# 0    29
# Name: count, dtype: int64
